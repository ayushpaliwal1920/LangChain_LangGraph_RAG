# %%
! pip install langchain langchain-core langchain-community pydantic duckduckgo-search
# Out:
# Requirement already satisfied: langchain in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (1.3.12)
# Requirement already satisfied: langchain-core in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (1.4.9)
# Requirement already satisfied: langchain-community in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: pydantic in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (2.13.4)
# Requirement already satisfied: duckduckgo-search in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (8.1.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain) (1.2.8)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-core) (0.10.1)
# Requirement already satisfied: packaging>=23.2.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-core) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (4.14.1)
# Requirement already satisfied: distro>=1.7.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: certifi in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=1.26.2 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-community) (2.5.1)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Requirement already satisfied: greenlet>=1 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# Requirement already satisfied: click>=8.1.8 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from duckduckgo-search) (8.4.2)
# Requirement already satisfied: primp>=0.15.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from duckduckgo-search) (1.3.1)
# Requirement already satisfied: lxml>=5.3.0 in /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages (from duckduckgo-search) (6.1.1)

# %% [markdown]
# # Built-in Tool : DuckDuckGo search

# %%
import sys
print(sys.executable)
# Out:
# /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/bin/python

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke("Fifa next match")

print(results)
# Out:
# /tmp/ipykernel_15713/3454719783.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchRun
# 4 days ago ... World Cup 2026, the biggest and most exciting edition of the tournament to date, is now under way as 48 teams compete in 104 matches. FIFA. 31 Mar 2026 ... FIFA World Cup 2026 quarter-final fixturesFIFA World Cup 2026 quarter-final fixtures · Thursday, 9 July 2026Thursday, 9 July 2026 · Friday, 10 July 2026Friday, 10 ... 16 hours ago ... Check FIFA World Cup 2026 today's match schedule, full fixtures, timings, and venues. Watch live matches and highlights on ZEE5. 11 Jun 2026 ... Football fans across the globe can follow the action from every match of the FIFA World Cup 2026™ from Thursday, 11 June to Sunday, 19 July, with the official ... 15 Oct 2025 ... MATCH SCHEDULE AT NYNJ STADIUM ... By clicking “Accept Cookies”, you agree to the storing of cookies on your device to enhance site navigation, analyze site usage ...

# %% [markdown]
# # Built-in- Shell Tool :

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

result = shell_tool.invoke("whoami")
print(result)
# Out:
# Executing command:
#  whoami
# ayush-paliwal
# /media/ayush-paliwal/New Volume2/LangChain & RAG Components/.venv/lib/python3.12/site-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(

# %% [markdown]
# # Check Langchain Tools : for more Tools
